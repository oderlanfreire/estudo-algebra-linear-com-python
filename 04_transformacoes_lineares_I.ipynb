# %% [markdown]
# # Transformações Lineares 1

# %% [markdown]
# Transformação linear é um tipo particular de função entre dois espaços vetoriais que preserva as operações de adição vetorial e multiplicação por escalar. Uma transformação linear também pode ser chamada de aplicação linear ou mapa linear.

# %% [markdown]
# ### Representando vetores

# %%
vetor = [(2,2)]
origens = [(0,-1),(0, 1),(0,0),(0,2)]

# %%
import matplotlib.pyplot as plt

# %%
# Definindo o vetor (2, 2)
vetor = [2, 2]
# Definindo as origens para o vetor
origens = [(0,-1),(0, 1),(0,0),(0,2)]

# Extraindo as coordenadas x e y das origens
origem_x = [origem[0] for origem in origens]
origem_y = [origem[1] for origem in origens]

# plot da figura
plt.figure()
plt.quiver(origem_x, origem_y,  [vetor[0]]*len(origem_x), [vetor[1]]*len(origem_y), angles="xy", scale_units="xy", scale=1, color="g")

# Configuraçõe adicionais do grafico
plt.xlim(-1, 5)
plt.ylim(-2, 5)
plt.xlabel('X')
plt.ylabel('Y')
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.gca().set_aspect('equal', adjustable="box")
plt.title("Vetor com diferentes pontos de origem")
# Out:
# Text(0.5, 1.0, 'Vetor com diferentes pontos de origem')

# %% [markdown]
# ### Base Canônica

# %% [markdown]
# A base canônica de um espaço vetorial ou de outras estruturas algébricas semelhantes é a base mais primitiva e intuitiva para a estrutura

# %%
vetor_x = [1, 0]
vetor_y = [0, 1]

plt.figure()
plt.quiver(0,0, vetor_x[0], vetor_x[1], angles="xy", scale_units="xy", scale=1, color="r", label="Eixo X")
plt.quiver(0, 0, vetor_y[0], vetor_y[1], angles="xy", scale_units="xy", scale=1, color="b", label="Eixo Y")


plt.xlim(-1,1)
plt.ylim(-1,1)
plt.xlabel("X")
plt.ylabel("Y")
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.gca().set_aspect("equal", adjustable="box")
plt.legend()
plt.title("Base Canônica")

plt.show()
